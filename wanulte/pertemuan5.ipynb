# %%
def tulis(text):
    print(text)

tulis("Halo")
# Out:
# Halo

# %%
def LuasPersegi(id,sisi):
    print('Luas Persegi', id,":" sisi+sisi)
    
LuasPersegi(4)
# Out:
# Luas 16

# %%
Sisi1 = int(input())
Sisi2 = int(input())
Sisi3 = int(input())
Sisi4 = int(input())

# LuasPersegi(1, Sisi1)
# LuasPersegi (2, Sisi2)
# LuasPersegi (3, Sisi3)
# LuasPersegi (4, Sisi4)
# print('Luas Bangun 1', Sisi1*Sisi1)
# print('Luas Bangun 2', Sisi2*Sisi2)
# print('Luas Bangun 3', Sisi3*Sisi3)
# print('Luas Bangun 4', Sisi4*Sisi4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       3 Sisi3 = int(input())
#       4 Sisi4 = int(input())
# ----> 6 LuasPersegi(1, Sisi1)
#       7 LuasPersegi (2, Sisi2)
#       8 LuasPersegi (3, Sisi3)
#
# TypeError: LuasPersegi() takes 1 positional argument but 2 were given

# %%
def tambah (a, b = 4):
    return a+b
print(tambah(2,1))
print(tambah(4))
# Out:
# 3
# 8

# %%
tambah(tambah(1,1), tambah(4))
# Out:
# 10

# %%
def Halo(*A):
    for i in A:
        print(i)
        
Halo("H","A","L")
# Out:
# H
# A
# L
